# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
from termcolor import colored
import empyrical as emp
from utils import *
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('../HMM_randomportfolio.csv')
df.pricingdate = df.pricingdate.astype('datetime64')
df = df.set_index(df.pricingdate).drop('pricingdate', axis=1)
df['predicted'] = np.zeros(len(df.priceclose))
df
# Out:
#               priceclose        r1  signal  predicted
# pricingdate
# 2001-01-03    268.633857  0.012004       1        0.0
# 2001-01-04    266.142144 -0.009275       0        0.0
# 2001-01-05    253.156482 -0.048792       0        0.0
# 2001-01-08    245.341326 -0.030871       0        0.0
# 2001-01-09    247.053257  0.006978       1        0.0
# ...                  ...       ...     ...        ...
# 2022-05-24   1871.590002  0.002630       1        0.0
# 2022-05-25   1913.690022  0.022494       1        0.0
# 2022-05-26   1923.819968  0.005293       1        0.0
# 2022-05-27   1967.990009  0.022960       1        0.0
# 2022-05-31   1934.319976 -0.017109       0        0.0
#
# [5386 rows x 4 columns]

# %%
#Walk-Forward Data Preparation
experiment = WalkForward(df, 'signal', step=1, start_interval = 400)

# %%
plt.figure(figsize = (19,9))
plt.plot(experiment[-2]['universe_train'].priceclose)
plt.title('Price of the first window')
# Out:
# Text(0.5, 1.0, 'Price of the first window')

# %%
S = ['B','S'] # buy, sell states

# %%
n_visible = len(df.signal.unique())
n_hidden = len(S)

# %%
def forward(V, A, B, pi):
    T = V.shape[0]
    N = A.shape[0]
    
    alpha = np.zeros((T,N))
    alpha[0] = pi[0] * B[:,V[0]]  
    for t in range(0,T-1): alpha[t+1] = np.array([alpha[t,:].dot(A[:,j]) * (B[j,V[t+1]]) for j in range(N)])
            
    return alpha

# %%
def backward(V, A, B):
    T = V.shape[0]
    N = A.shape[0]
    
    beta = np.zeros((T,N))
    beta[T-1] = np.ones((N))
    for t in range(T-2, -1, -1): beta[t] = np.array([(beta[t+1,:] * B[:,V[t+1]]).dot(A[j,:]) for j in range(N)])
            
    return beta

# %%
def viterbi(V,A,B,pi):
    T = V.shape[0]
    N = A.shape[0]

    alpha = forward(V, A, B, pi)
    beta = backward(V, A, B)

    xi = np.zeros((T, N, N))
    for t in range(T-1):
        denominator = sum(alpha[t,:].dot(A[:,:]) * B[:,V[t+1]] * beta[t+1,:])
        for i in range(N):
            for j in range(N):
                numerator = alpha[t,i] * A[i,j] * (B[j,V[t+1]]) * beta[t+1,j] 
                xi[t,i,j] = numerator / denominator 

           # note: gamma can be also computed as
    gamma = np.zeros((T,N))
    for t in range(T): gamma[t] = np.array([sum(xi[t,i,:]) for i in range(N)])

    return gamma, xi

# %%
def baum_welch(V, A, B, pi, max_iter=100, epsilon=1e-5, verbose=True):
    T = V.shape[0]
    N = A.shape[0]
    
    # initialization: for the first iteration, our estimated parameters will be the initial ones
    A_bar = A
    B_bar = B
    pi_bar = pi
    
    for iteration in range(max_iter):
        gamma, xi = viterbi(V, A_bar, B_bar, pi_bar)

        # expectation-maximization step
        pi_bar = np.array([gamma[0,i] for i in range(N)])

        prev = [A_bar, B_bar, pi_bar]
               
        A_bar = np.zeros((N,N))
        for i in range(N): A_bar[i] = np.array([xi[:-1,i,j].sum() / gamma[:-1,i].sum() for j in range(N)])

        B_bar = np.zeros(B.shape)
        for j in range(B.shape[0]):
            for k in range(B.shape[1]):
                # we need to define a list of times t_bar where V[t] is equal to k
                t_bar = [0,0]
                for i in [0,1]: t_bar[i] = [t for t in range(T) if V[t]==k]
                B_bar[j,k] = sum([gamma[t,j] for t in t_bar[k]]) / gamma[:,j].sum()
        
        A_delta = delta(A_bar, prev[0])
        B_delta = delta(B_bar, prev[1])
        pi_delta = delta(pi_bar, prev[2])
        
        e = A_delta + B_delta + pi_delta
        
        if verbose == True: print(f'iteration {iteration} - delta {e}')
        if e < epsilon: break

    return {'A_hat': A_bar, 'B_hat': B_bar, 'pi_hat': pi_bar, 'gamma': gamma}

# %%
#initialization of parameters
A_init = np.array([[.9,.1],
                  [.15,.85]])
B_init = np.array([[.8,.2],
                   [.2,.8]])
pi_init = np.array([1.05/2,.95/2])

# %%
est= baum_welch(experiment[-55]['train_input'], A_init, B_init, pi_init)
# Out:
# iteration 0 - delta 0.04632588828180825
# iteration 1 - delta 0.009459446604339884
# iteration 2 - delta 0.0036021728287349555
# iteration 3 - delta 0.001758803739213095
# iteration 4 - delta 0.000992691881304731
# iteration 5 - delta 0.0006153338355967508
# iteration 6 - delta 0.0004068044441278785
# iteration 7 - delta 0.00028163153331692764
# iteration 8 - delta 0.00020170014677709316
# iteration 9 - delta 0.00014817873024440778
# iteration 10 - delta 0.00011099036609186207
# iteration 11 - delta 8.43856823523244e-05
# iteration 12 - delta 6.49064271989584e-05
# iteration 13 - delta 5.0378159534199495e-05
# iteration 14 - delta 3.938112695498977e-05
# iteration 15 - delta 3.0957877068181566e-05
# iteration 16 - delta 2.4444504898751814e-05
# iteration 17 - delta 1.9369494598774748e-05
# iteration 18 - delta 1.539101296074089e-05
# iteration 19 - delta 1.2256853214808586e-05
# iteration 20 - delta 9.778142083286624e-06

# %%
gennaro = est['gamma']
gennaro
# Out:
# array([[0.5049059 , 0.4950941 ],
#        [0.49717048, 0.50282952],
#        [0.49961775, 0.50038225],
#        [0.51276498, 0.48723502],
#        [0.5114302 , 0.4885698 ],
#        [0.5232598 , 0.4767402 ],
#        [0.52281566, 0.47718434],
#        [0.51000239, 0.48999761],
#        [0.51005683, 0.48994317],
#        [0.49505749, 0.50494251],
#        [0.48980792, 0.51019208],
#        [0.49319856, 0.50680144],
#        [0.50594605, 0.49405395],
#        [0.5027829 , 0.4972171 ],
#        [0.51097617, 0.48902383],
#        [0.5043172 , 0.4956828 ],
#        [0.50933475, 0.49066525],
#        [0.52708936, 0.47291064],
#        [0.53336034, 0.46663966],
#        [0.52949451, 0.47050549],
#        [0.51466161, 0.48533839],
#        [0.51367051, 0.48632949],
#        [0.49838274, 0.50161726],
#        [0.49354053, 0.50645947],
#        [0.49812043, 0.50187957],
#        [0.51309046, 0.48690954],
#        [0.51364289, 0.48635711],
#        [0.52782389, 0.47217611],
#        [0.53068743, 0.46931257],
#        [0.52284852, 0.47715148],
#        [0.53055089, 0.46944911],
#        [0.52752209, 0.47247791],
#        [0.51311161, 0.48688839],
#        [0.51221929, 0.48778071],
#        [0.52465655, 0.47534345],
#        [0.52511306, 0.47488694],
#        [0.51368687, 0.48631313],
#        [0.488041  , 0.511959  ],
#        [0.49384902, 0.50615098],
#        [0.50915466, 0.49084534],
#        [0.50921674, 0.49078326],
#        [0.52198258, 0.47801742],
#        [0.52220407, 0.47779593],
#        [0.50992876, 0.49007124],
#        [0.51050515, 0.48949485],
#        [0.52405508, 0.47594492],
#        [0.52549518, 0.47450482],
#        [0.54303616, 0.45696384],
#        [0.55246123, 0.44753877],
#        [0.5557946 , 0.4442054 ],
#        [0.55375218, 0.44624782],
#        [0.54589531, 0.45410469],
#        [0.53053659, 0.46946341],
#        [0.53232272, 0.46767728],
#        [0.52375111, 0.47624889],
#        [0.5309087 , 0.4690913 ],
#        [0.52741103, 0.47258897],
#        [0.5125069 , 0.4874931 ],
#        [0.51099567, 0.48900433],
#        [0.49462395, 0.50537605],
#        [0.48791422, 0.51208578],
#        [0.4894483 , 0.5105517 ],
#        [0.49955045, 0.50044955],
#        [0.49240637, 0.50759363],
#        [0.4944475 , 0.5055525 ],
#        [0.50610525, 0.49389475],
#        [0.50188712, 0.49811288],
#        [0.50883773, 0.49116227],
#        [0.50048743, 0.49951257],
#        [0.50301385, 0.49698615],
#        [0.48901392, 0.51098608],
#        [0.483497  , 0.516503  ],
#        [0.48529703, 0.51470297],
#        [0.49479446, 0.50520554],
#        [0.5139967 , 0.4860033 ],
#        [0.51895838, 0.48104162],
#        [0.53866616, 0.46133384],
#        [0.54932421, 0.45067579],
#        [0.55322156, 0.44677844],
#        [0.55119522, 0.44880478],
#        [0.54281002, 0.45718998],
#        [0.52626506, 0.47373494],
#        [0.52597925, 0.47402075],
#        [0.51399224, 0.48600776],
#        [0.51570391, 0.48429609],
#        [0.53147605, 0.46852395],
#        [0.53669614, 0.46330386],
#        [0.53248531, 0.46751469],
#        [0.54582175, 0.45417825],
#        [0.55164743, 0.44835257],
#        [0.55121352, 0.44878648],
#        [0.54442683, 0.45557317],
#        [0.52982978, 0.47017022],
#        [0.53222982, 0.46777018],
#        [0.52425307, 0.47574693],
#        [0.50418637, 0.49581363],
#        [0.4957886 , 0.5042114 ],
#        [0.49728478, 0.50271522],
#        [0.50899116, 0.49100884],
#        [0.50542629, 0.49457371],
#        [0.51377018, 0.48622982],
#        [0.5078484 , 0.4921516 ],
#        [0.51434069, 0.48565931],
#        [0.50668737, 0.49331263],
#        [0.51120588, 0.48879412],
#        [0.52885129, 0.47114871],
#        [0.53538465, 0.46461535],
#        [0.53220915, 0.46779085],
#        [0.51864278, 0.48135722],
#        [0.51974567, 0.48025433],
#        [0.53575092, 0.46424908],
#        [0.54210574, 0.45789426],
#        [0.54017495, 0.45982505],
#        [0.52954387, 0.47045613],
#        [0.50792928, 0.49207072],
#        [0.49876879, 0.50123121],
#        [0.50012621, 0.49987379],
#        [0.51228845, 0.48771155],
#        [0.50987035, 0.49012965],
#        [0.52028998, 0.47971002],
#        [0.51781291, 0.48218709],
#        [0.52983061, 0.47016939],
#        [0.5309591 , 0.4690409 ],
#        [0.52144076, 0.47855924],
#        [0.        , 0.        ]])

# %%
state= np.ones(len(gennaro))
for t in range(len(gennaro)): state[t] = np.argmax(gennaro[t])
experiment[-55]['state'] = state

# %%
plt.figure(figsize=(15,10))
plt.plot(experiment[-55]['universe_train'].priceclose, color='black',alpha=.8)
plt.fill_between(experiment[-55]['universe_train'].index,experiment[-55]['universe_train'].priceclose,800,where=experiment[-55]['state']==0, color='red', alpha=.7)
plt.fill_between(experiment[-55]['universe_train'].index,experiment[-55]['universe_train'].priceclose,800,where=experiment[-55]['state']==1, color='green', alpha=.7)

# %%
 # conditional distribution of r1 given the state
(experiment[-55]['universe_train']['r1'][experiment[-55]['state']==0]*100).plot.density()
(experiment[-55]['universe_train']['r1'][experiment[-55]['state']==1]*100).plot.density()
plt.legend(['Sell','Buy'])
plt.xlabel('% of increasing return')
# Out:
# Text(0.5, 0, '% of increasing return')

# %%
predictions = []
for exp in range(len(experiment)):
    train = baum_welch(experiment[exp]['train_input'], A_init, B_init, pi_init, max_iter=1000, epsilon=1e-19, verbose = 0)
    prediction = (forward(experiment[exp+1]['train_input'], train['A_hat'], train['B_hat'], train['pi_hat']))[-1].dot(train['A_hat']).argmax()
    print('experiment n.', exp, 'and his state prediction is:', prediction)
    predictions.append(prediction)
# Out:
# experiment n. 0 and his state prediction is: 1
# experiment n. 1 and his state prediction is: 1
# experiment n. 2 and his state prediction is: 1
# experiment n. 3 and his state prediction is: 0
# experiment n. 4 and his state prediction is: 0
# experiment n. 5 and his state prediction is: 0
# experiment n. 6 and his state prediction is: 1
# experiment n. 7 and his state prediction is: 0
# experiment n. 8 and his state prediction is: 0
# experiment n. 9 and his state prediction is: 1
# experiment n. 10 and his state prediction is: 0
# experiment n. 11 and his state prediction is: 0
# experiment n. 12 and his state prediction is: 0
# experiment n. 13 and his state prediction is: 0
# experiment n. 14 and his state prediction is: 0
# experiment n. 15 and his state prediction is: 0
# experiment n. 16 and his state prediction is: 0
# experiment n. 17 and his state prediction is: 0
# experiment n. 18 and his state prediction is: 1
# experiment n. 19 and his state prediction is: 0
# experiment n. 20 and his state prediction is: 1
# experiment n. 21 and his state prediction is: 1
# experiment n. 22 and his state prediction is: 0
# experiment n. 23 and his state prediction is: 0
# experiment n. 24 and his state prediction is: 0
# experiment n. 25 and his state prediction is: 1
# experiment n. 26 and his state prediction is: 0
# experiment n. 27 and his state prediction is: 0
# experiment n. 28 and his state prediction is: 1
# experiment n. 29 and his state prediction is: 0
# experiment n. 30 and his state prediction is: 1
# experiment n. 31 and his state prediction is: 1
# experiment n. 32 and his state prediction is: 0
# experiment n. 33 and his state prediction is: 1
# experiment n. 34 and his state prediction is: 1
# experiment n. 35 and his state prediction is: 0
# experiment n. 36 and his state prediction is: 0
# experiment n. 37 and his state prediction is: 1
# experiment n. 38 and his state prediction is: 0
# experiment n. 39 and his state prediction is: 0
# experiment n. 40 and his state prediction is: 0
# experiment n. 41 and his state prediction is: 0
# experiment n. 42 and his state prediction is: 0
# experiment n. 43 and his state prediction is: 0
# experiment n. 44 and his state prediction is: 1
# experiment n. 45 and his state prediction is: 1
# experiment n. 46 and his state prediction is: 0
# experiment n. 47 and his state prediction is: 1
# experiment n. 48 and his state prediction is: 1
# experiment n. 49 and his state prediction is: 1
# experiment n. 50 and his state prediction is: 1
# experiment n. 51 and his state prediction is: 1
# experiment n. 52 and his state prediction is: 1
# experiment n. 53 and his state prediction is: 1
# experiment n. 54 and his state prediction is: 0
# experiment n. 55 and his state prediction is: 0

# %%
pd.Series(predictions).value_counts()

# %%
confusion_matrix(pd.Series(df.signal.head(1232)),pd.Series(predictions), normalize = 'true')

# %%
hh = pd.concat([df.reset_index(), pd.Series(predictions)], axis = 1).dropna().rename(columns={0:'prediction_state'})

# %%
hh.pricingdate = pd.to_datetime(hh.pricingdate)
hh = hh.set_index('pricingdate')

# %%
performance_extd(hh.prediction_state*hh.r1, color = 'blue')
performance_extd(hh.r1)

# %%
strategy = (prediction * experiment[1]['universe_train'][-1:]['r1'])

# %%
experiment[0]['state'][-2:-1] * experiment[0]['universe_train'][-2:-1]['r1']

# %%
experiment[0]['universe_train'][-2:-1]

# %%
experiment[0]['universe_train'][-2:-1].priceclose + experiment[0]['universe_train'][-2:-1].r1[]

# %%
prediction = rolling1[-2:-1].priceclose + (rolling1.r1[rolling1.state==rolling1[-2:-1].state[0]].mean())*rolling1[-2:-1].priceclose
df.predicted[298] = prediction[0]
prediction

# %%
actual = rolling1[-1:].priceclose
actual

# %%
loss = (prediction[0] - actual[0])**2
loss

# %%
loss = []
width = 50

warnings.filterwarnings("ignore")
for n in range(width,100):
    rolling = df[(n-width):n]
    state = np.empty(width)
    est = baum_welch(rolling.signal, A_init, B_init, pi_init, print_states = False)
    
    for t in range(width-1): state[t] = np.argmax(est['gamma'][t])
    rolling['state'] = state[:width]
    
    prediction = rolling[-2:-1].priceclose + (rolling.r1[rolling.state==rolling[-2:-1].state[0]].mean())*rolling[-2:-1].priceclose
    df.predicted[n-1] = prediction[0]
    actual = rolling[-1:].priceclose
    loss.append((prediction[0] - actual[0])**2)
    print(f'iteration:{n}')
    
loss = np.array(loss)
total_loss = loss.sum()
mse = loss.mean()

# %%
mse

# %%
plt.figure(figsize=(15,10))
plt.plot(df.priceclose)
plt.plot(df.predicted)
plt.xlim((17700,17900))
plt.ylim((1150,1450))
plt.legend(('Actual', 'Predicted'))

# %%
mse

# %%
'''
def viterbi(V, a, b, initial_distribution):
    T = V.shape[0]
    M = a.shape[0]
 
    omega = np.zeros((T, M))
    omega[0, :] = np.log(initial_distribution * b[:, V[0]])
 
    prev = np.zeros((T - 1, M))
 
    for t in range(1, T):
        for j in range(M):
            # Same as Forward Probability
            probability = omega[t - 1] + np.log(a[:, j]) + np.log(b[j, V[t]])
 
            # This is our most probable state given previous state at time t (1)
            prev[t - 1, j] = np.argmax(probability)
 
            # This is the probability of the most probable state (2)
            omega[t, j] = np.max(probability)
 
    # Path Array
    S = np.zeros(T)
 
    # Find the most probable last hidden state
    last_state = np.argmax(omega[T - 1, :])
 
    S[0] = last_state
 
    backtrack_index = 1
    for i in range(T - 2, -1, -1):
        S[backtrack_index] = prev[i, int(last_state)]
        last_state = prev[i, int(last_state)]
        backtrack_index += 1
 
    # Flip the path array since we were backtracking
    S = np.flip(S, axis=0)
 
    # Convert numeric values to actual hidden states
    result = []
    for s in S:
        if s == 0:
            result.append("A")
        else:
            result.append("B")
 
    return result
'''
